# %%
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.orm import Session

# %%
data_path = "WorldCupMatches.csv"
soccer1_df = pd.read_csv(data_path)
soccer1_df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
soccer1_df = soccer1_df.drop(soccer1_df.columns[[1]], axis=1) 
soccer1_df
# Out:
#         Year    Stage         Stadium         City Home Team Name  \
# 0     1930.0  Group 1         Pocitos  Montevideo          France
# 1     1930.0  Group 4  Parque Central  Montevideo             USA
# 2     1930.0  Group 2  Parque Central  Montevideo      Yugoslavia
# 3     1930.0  Group 3         Pocitos  Montevideo         Romania
# 4     1930.0  Group 1  Parque Central  Montevideo       Argentina
# ...      ...      ...             ...          ...            ...
# 4567     NaN      NaN             NaN          NaN            NaN
# 4568     NaN      NaN             NaN          NaN            NaN
# 4569     NaN      NaN             NaN          NaN            NaN
# 4570     NaN      NaN             NaN          NaN            NaN
# 4571     NaN      NaN             NaN          NaN            NaN
#
#       Home Team Goals  Away Team Goals Away Team Name Win conditions  \
# 0                 4.0              1.0         Mexico
# ...

# %%
# soccer1_df = soccer1_df.drop("MatchID", axis=1)

# %%
soccer1_df
# Out:
#         Year    Stage         Stadium         City Home Team Name  \
# 0     1930.0  Group 1         Pocitos  Montevideo          France
# 1     1930.0  Group 4  Parque Central  Montevideo             USA
# 2     1930.0  Group 2  Parque Central  Montevideo      Yugoslavia
# 3     1930.0  Group 3         Pocitos  Montevideo         Romania
# 4     1930.0  Group 1  Parque Central  Montevideo       Argentina
# ...      ...      ...             ...          ...            ...
# 4567     NaN      NaN             NaN          NaN            NaN
# 4568     NaN      NaN             NaN          NaN            NaN
# 4569     NaN      NaN             NaN          NaN            NaN
# 4570     NaN      NaN             NaN          NaN            NaN
# 4571     NaN      NaN             NaN          NaN            NaN
#
#       Home Team Goals  Away Team Goals Away Team Name Win conditions  \
# 0                 4.0              1.0         Mexico
# ...

# %%
data_path = "WorldCupPlayers.csv"
soccer2_df = pd.read_csv(data_path)
soccer2_df.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
# merge_df = pd.merge(soccer1_df,soccer2_df, how= "inner", on ="RoundID")
# merge_df.head()

# %%
# merge_df.round({"Year":0, "Away Team Goals":0, "Attendance":0})
soccer1_df.dtypes
# Out:
# Year                    float64
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
merge_df['Home Team Goals'] = merge_df['Home Team Goals'].astype(int) 
soccer1_df.dtypes
# merge_df
# Out:
# Year                    float64
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
merge_df['Home Team Goals'] = merge_df['Home Team Goals'].astype(int) 
soccer1_df.dtypes
# merge_df
# Out:
# Year                    float64
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
merge_df['Year'] = merge_df['Year'].astype(int) 
soccer1_df.dtypes
#soccer1_df
# Out:
# Year                    float64
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
merge_df['Away Team Goals'] = merge_df['Away Team Goals'].astype(int) 
#soccer1_df.dtypes
#soccer1_df

# %%
# merge_df['Attendance'] = merge_df['Attendance'].astype(int) 
# merge_df.dtypes
# soccer1_df

# %%
visualization1_df = soccer1_df[["Year", "Stage", "Home Team Goals", "Away Team Goals","Attendance","MatchID"]].dropna()
visualization1_df
# Out:
#        Year                     Stage  Home Team Goals  Away Team Goals  \
# 0    1930.0                   Group 1              4.0              1.0
# 1    1930.0                   Group 4              3.0              0.0
# 2    1930.0                   Group 2              2.0              1.0
# 3    1930.0                   Group 3              3.0              1.0
# 4    1930.0                   Group 1              1.0              0.0
# ..      ...                       ...              ...              ...
# 847  2014.0            Quarter-finals              0.0              0.0
# 848  2014.0               Semi-finals              1.0              7.0
# 849  2014.0               Semi-finals              0.0              0.0
# 850  2014.0  Play-off for third place              0.0              3.0
# 851  2014.0                     Final              1.0              0.0
#
#      Attendance      MatchID
# 0        4444.0       1096.0
# 1       18346.0       1090.0
# ...

# %%
visualization2_df= soccer1_df[["Year", "Home Team Goals", "Away Team Goals","City","MatchID"]].dropna()
visualization2_df
# Out:
#        Year  Home Team Goals  Away Team Goals             City      MatchID
# 0    1930.0              4.0              1.0      Montevideo        1096.0
# 1    1930.0              3.0              0.0      Montevideo        1090.0
# 2    1930.0              2.0              1.0      Montevideo        1093.0
# 3    1930.0              3.0              1.0      Montevideo        1098.0
# 4    1930.0              1.0              0.0      Montevideo        1085.0
# ..      ...              ...              ...              ...          ...
# 847  2014.0              0.0              0.0        Salvador   300186488.0
# 848  2014.0              1.0              7.0  Belo Horizonte   300186474.0
# 849  2014.0              0.0              0.0       Sao Paulo   300186490.0
# 850  2014.0              0.0              3.0        Brasilia   300186502.0
# 851  2014.0              1.0              0.0  Rio De Janeiro   300186501.0
#
# [852 rows x 5 columns]

# %%
data_path = "WorldCups.csv"
soccer3_df = pd.read_csv(data_path)
soccer3_df.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607
